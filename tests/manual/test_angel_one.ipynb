# %%
cd ..
# Out:
# /Users/apurv/Desktop/open-source/india-stock-api

# %%
from india_stocks_api.brokers import AngelOne
# Out:
# Using cached data from today.

# %% [markdown]
# ### Get Headers

# %%
params = {
    "user_id": "A1357374",
    "pin": "8989",
    "totpstr": "EL7KI5RGSJ5ZXZ625FDETRO44I",
    "api_key": "Wphmjc9u",
    "api_secret": "not_needed",
}

# %%
headers = AngelOne.generate_headers(params=params)

# %%
headers
# Out:
# {'headers': {'Content-type': 'application/json',
#   'X-ClientLocalIP': '127.0.0.1',
#   'X-ClientPublicIP': '106.193.147.98',
#   'X-MACAddress': '00:00:00:00:00:00',
#   'Accept': 'application/json',
#   'X-PrivateKey': 'Wphmjc9u',
#   'X-UserType': 'USER',
#   'X-SourceID': 'WEB',
#   'Authorization': 'Bearer eyJhbGciOiJIUzUxMiJ9.....ljo425KNZQNMtv3kRRrUOEF0Rz4ulVVTGgks8ofSsGsqVMoN0tpiK4jyWE3EzAkygcsqqI0LiUJwxWtIDKmiqQ',
#   'x-api-key': 'nBmFCnuK',
#   'x-client-code': 'A1357374',
#   'x-feed-token': 'eyJhbGciOiJIUzUxMiJ9.eyJ1c2VybmFtZSI6IkExMzU3Mzc0IiwiaWF0IjoxNzM0MDAwMDI1LCJleHAiOjE3MzQwODY0MjV9.A395V-e2xkALmvnqPf_WdmPYAN7ke-m_8WvwFcybt9kubyn-i9032oQtC6IB5ogXEUWPeand3qeszkew40KvFg'}}

# %%
AngelOne.profile(headers)
# Out:
# {'clientId': 'A1357374',
#  'name': 'APURV  SALUNKE',
#  'emailId': '',
#  'mobileNo': '',
#  'pan': '',
#  'address': '',
#  'bankName': '',
#  'bankBranchName': None,
#  'bankAccNo': '',
#  'exchangesEnabled': ['nse_fo',
#   'nse_cm',
#   'cde_fo',
#   'ncx_fo',
#   'bse_fo',
#   'bse_cm',
#   'mcx_fo'],
#  'enabled': True,
#  'info': {'clientcode': 'A1357374',
#   'name': 'APURV  SALUNKE',
#   'email': '',
#   'mobileno': '',
#   'exchanges': ['nse_fo',
#    'nse_cm',
#    'cde_fo',
#    'ncx_fo',
#    'bse_fo',
#    'bse_cm',
#    'mcx_fo'],
#   'products': ['MARGIN', 'MIS', 'NRML', 'CNC', 'CO', 'BO'],
#   'lastlogintime': '',
#   'broker': ''}}

# %% [markdown]
# ### Create Eq Tokens

# %%
AngelOne.create_indices()
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 AngelOne.create_indices()
#
# File ~/Desktop/open-source/india-stock-api/india_stocks_api/brokers/angel_one.py:322, in AngelOne.create_indices(cls)
#     313 @classmethod
#     314 def create_indices(cls) -> dict:
#     315     """
#     316     Downloads all the Broker Indices Token data.
#     317     Stores them in the AngelOne.indices Dictionary.
#    (...)
#     320         dict: Unified indian-stocks-api indices format.
#     321     """
# ...

# %%
historicParam={
        "exchange": "NSE",
        "symboltoken": "3045",
        "interval": "ONE_MINUTE",
        "fromdate": "2021-02-08 09:00", 
        "todate": "2021-02-08 09:16"
}

# %%
AngelOne.get_candle_data()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 AngelOne.get_candle_data()
#
# TypeError: AngelOne.get_candle_data() missing 6 required positional arguments: 'symbol', 'exchange', 'interval', 'from_date', 'to_date', and 'headers'
